# %%
import pandas as pd

elcomercio = pd.read_csv('clean_elcomercio_2020_06_30_articles.csv')
eluniversal = pd.read_csv('clean_eluniversal_2020_06_30_articles.csv')
# %matplotlib inline
elcomercio['n_tokens_ntitle'].plot(style='k.')
eluniversal['n_tokens_ntitle'].plot(style='r.')

# %%
all_newspapers = pd.concat([eluniversal, elcomercio])

grouped = all_newspapers.groupby('newspaper_uid')

grouped.hist()
# Out:
# newspaper_uid
# elcomercio     [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# eluniversal    [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# dtype: object

# %%
grouped['n_tokens_nbody'].agg(['min', 'mean', 'max'])
# Out:
#                min        mean   max
# newspaper_uid
# elcomercio     144  489.633333  1923
# eluniversal      9  260.507576  1051

# %%
grouped.plot()
# Out:
# newspaper_uid
# elcomercio     AxesSubplot(0.125,0.125;0.775x0.755)
# eluniversal    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

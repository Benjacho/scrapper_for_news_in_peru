# %%
import pandas as pd
import numpy as np

data = pd.read_csv('clean_elcomercio_2020_06_30_articles.csv')

data
# Out:
#                                  uid  \
# 0   7d731fe2bbfdf57b843e96fa333f283d
# 1   1a230a1da7ae005be6c323b8d56a2fc1
# 2   d130443558ed02112297a516476802c5
# 3   d182d0fc7c7e057bcc2db936d677889d
# 4   aa3603992144bb4db6630b7ae148b383
# 5   da03df6bd2e265d9a948ae905cf280d4
# 6   0674c778937b57cc499779be43645201
# 7   b370ae106d10727e65eb8c89195d7b01
# 8   ba64c049c36442f609e64dfb869dc1b7
# 9   ac9365648085ffa91b4a7882f8d71e33
# 10  fad84b4b2a33b5c93c6a6795abafe80c
# 11  ac5cd4f1ff00b0982cf7292ca3cd8385
# 12  fed0941b1a71e51e2829bbbd094ec1b2
# 13  ab6f999412fd9ab93eb1066a47191d22
# 14  e776304af51de7e32eb692aeeff9ce88
# 15  6f26913b0867eaab6872c046d84f8cff
# 16  42401340866638a2313349693caba80c
# 17  40be147270a90cd800d63c2014c22f1a
# 18  ed595dca50885de447ccf33bc6728946
# 19  68c0e12eb8ef4857bbdd47464e65b04e
# 20  43251679471234dbe34d199a2806b512
# 21  1789d4481c2f6a51f089e86ca2df9a1a
# 22  da663dea1d47e668863e58e0acf546b2
# 23  f6caacab1efd777508ab35e54fc61970
# ...
